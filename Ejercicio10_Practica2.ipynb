# %%
#Ejercicio 10.

nombres = ''' 'Agustin', 'Alan', 'Andrés', 'Ariadna', 'Bautista', 'CAROLINA', 'CESAR', 'David',
'Diego', 'Dolores', 'DYLAN', 'ELIANA', 'Emanuel', 'Fabián', 'Facundo', 'Francsica', 
'FEDERICO', 'Fernanda', 'GONZALO', 'Gregorio', 'Ignacio', 'Jonathan', 'Joaquina', 'Jorge',
'JOSE', 'Javier', 'Joaquín' , 'Julian', 'Julieta', 'Luciana','LAUTARO', 'Leonel', 'Luisa', 
'Luis', 'Marcos', 'María', 'MATEO', 'Matias', 'Nicolás', 'Nancy', 'Noelia', 'Pablo', 
'Priscila', 'Sabrina', 'Tomás', 'Ulises', 'Yanina' '''
notas_1 = [81, 60, 72, 24, 15, 91, 12, 70, 29, 42, 16, 3, 35, 67, 10, 57, 11, 69, 12,
13, 86, 48, 65, 51, 41, 87, 43, 10, 87, 91, 15, 44, 85, 73, 37, 42, 95, 18,
74, 60, 9, 65, 93, 63, 74]

notas_2 = [30, 95, 28, 84, 84, 43, 66, 51, 4, 11, 58, 10, 13, 34, 96, 71, 86, 37, 64,
87, 14, 14, 49, 27, 55, 69, 77, 59, 57, 40, 96, 24, 30, 73, 95, 19, 47, 15,
39, 15, 74, 33, 57, 10]

#Inciso A.
def todas_notas ():
    return set(zip(notas_1,notas_2))
todas_las_notas = todas_notas()
#print(todas_las_notas)

#Inciso B.
def promedios_estudiantes ():
    promedios = list(map(lambda a, b: (a+b)/2,notas_1,notas_2))
    nombre_y_promedio={nombre: promedio for nombre, promedio in zip(nombres.split(','),promedios)}
    return nombre_y_promedio

todos_los_promedios = promedios_estudiantes()
#print(todos_los_promedios)

#Inciso C.
def promedio_general():
    for elem in todos_los_promedios.items():
        prom_general = sum(todos_los_promedios.values()) / len(todos_los_promedios)
    return prom_general

promedio_curso = promedio_general()
#print(prom_general)

#Inciso D.
def prom_mas_alto():
    mas_alto = max(todos_los_promedios.items(), key= lambda nombre: nombre[1])[0]
    return mas_alto

mejor_promedio = prom_mas_alto()
#print(mejor_promedio)

#Inciso E.
def nota_mas_baja():
    notas = tuple(zip(notas_1,notas_2)) #creo una tupla de tuplas con ambas notas.
    nombre_y_notas = dict(zip(nombres.split(','),notas)) #creo un diccinario con el nombre como clave, y una tupla con las 2 notas.
    mas_baja = min(nombre_y_notas, key=lambda nombre: nombre_y_notas[nombre])
    return mas_baja

estudiante = nota_mas_baja()
#print(estudiante)
